# %%
import pandas as pd
import matplotlib.pyplot as plt
#Import all the basic modules we will be needing for this project

# %%
df = pd.read_csv('data.csv')
df.head()
#Here, we display the first five data from the data set
# Out:
#    Time  Lane 1  Lane 2  Lane 3  Lane 4  Total Count
# 0  6.00      14      15      10      21           60
# 1  6.15      18      19      11      19           67
# 2  6.30      25      29      19      23           96
# 3  6.45      29      39      21      28          117
# 4  7.00      41      56      33      41          171

# %%
df
#This is the display of the whole data, partially returned for viewing purposes
# Out:
#      Time  Lane 1  Lane 2  Lane 3  Lane 4  Total Count
# 0    6.00      14      15      10      21           60
# 1    6.15      18      19      11      19           67
# 2    6.30      25      29      19      23           96
# 3    6.45      29      39      21      28          117
# 4    7.00      41      56      33      41          171
# 5    7.15      53      49      67      55          224
# 6    7.30      48      32      33      39          152
# 7    7.45      23      15      21      23           82
# 8    8.00      16      18      15      19           68
# 9    8.15       8      11      14      17           50
# 10   8.30      15      19      10      15           59
# 11   8.45      10      12      18       6           46
# 12   9.15      11       8       9      10           38
# 13   9.30       9      11       7      12           39
# 14   9.45      15      13      11       9           48
# 15  10.15       8      11      14      10           43
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(df['Time'],df['Lane 1'])
plt.show()

plt.figure(figsize=(20,5))
plt.plot(df['Time'],df['Lane 2'])
plt.show()

plt.figure(figsize=(20,5))
plt.plot(df['Time'],df['Lane 3'])
plt.show()

plt.figure(figsize=(20,5))
plt.plot(df['Time'],df['Lane 4'])
plt.show()
#Visualization of the growth of traffic in the lanes specific time range collected

# %%
plt.figure(figsize=(20,5))
plt.plot(df['Time'],df['Total Count'])
plt.show()
#Visualization of the growth of traffic in the junction specific time range collected
